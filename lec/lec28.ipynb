# %%
import matplotlib
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
import numpy as np
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Lecture 28 ##

# %%
united = Table.read_table('united_summer2015.csv')

# %%
united.hist('Delay', bins = np.arange(-20, 300, 10))

# %%
delays = united.column('Delay')
mean_delay = np.mean(delays)
sd_delay = np.std(delays)

mean_delay, sd_delay
# Out:
# (16.658155515370705, 39.480199851609314)

# %%
def one_sample_mean(sample_size):
    sampled_flights = united.sample(sample_size)
    return np.mean(sampled_flights.column('Delay'))

# %%
def ten_thousand_sample_means(sample_size):
    means = make_array()
    for i in np.arange(10000):
        means = np.append(means, one_sample_mean(sample_size))
    return means

# %%
"""Empirical distribution of random sample means"""

def plot_sample_means(sample_size):
    means = ten_thousand_sample_means(sample_size)
    sample_means = Table().with_column('Sample Means', means)
    
    # Display empirical histogram and print all relevant quantities
    sample_means.hist(bins=20)
    plots.xlabel('Sample Means')
    plots.title('Sample Size ' + str(sample_size))
    print("Sample size: ", sample_size)
    print("Population mean:", np.mean(united.column('Delay')))
    print("Average of sample means: ", np.mean(means))
    print("Population SD:", np.std(united.column('Delay')))
    print("SD of sample means:", np.std(means))

# %%
plot_sample_means(100)
# Out:
# Sample size:  100
# Population mean: 16.658155515370705
# Average of sample means:  16.639699
# Population SD: 39.480199851609314
# SD of sample means: 3.942995855868859

# %%
plot_sample_means(400)
# Out:
# Sample size:  400
# Population mean: 16.658155515370705
# Average of sample means:  16.6574485
# Population SD: 39.480199851609314
# SD of sample means: 1.9783465674895664

# %%
plot_sample_means(900)
# Out:
# Sample size:  900
# Population mean: 16.658155515370705
# Average of sample means:  16.670268555555555
# Population SD: 39.480199851609314
# SD of sample means: 1.3010319775162673

# %%
sd_delay
# Out:
# 39.480199851609314

# %% [markdown]
# ## SD of 0/1 Population ##

# %%
# Population of size 10

ones = 2
zero_one_population = ...
zero_one_population

# %%
sd_table = Table().with_column(
    'Population Proportion of Ones', np.arange(1, 10)/10,
    'Population SD', pop_SDs
)
